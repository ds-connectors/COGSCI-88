# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Read in experimental data collected in-class 
df = pd.read_csv('session3_data.csv')

# Convert pandas data frames to arrays (done for you)

# Response times for the upward and downward face stimuli
face_up = df.as_matrix(columns=2) 
face_down = df.as_matrix(columns=0)

# Response times for the upward and downward object stimuli
obj_up = df.as_matrix(columns=3)
obj_down = df.as_matrix(columns=1)

# Scatter-plot response times in each trial at x = 1 (face-up),2 (face-down),3 (obj-up),4 (obj-down)

# Label the axes

plt.show()

# Write a python function 'standev' that computes standard deviation (sd) of an array (a)
def standev(a):

    return sd

# Compute and report the means and standard deviations for each trial

#print(face_up_mn)
#print(face_down_mn)
#print(face_up_sd)
#print(face_down_sd)

#print(obj_up_mn)
#print(obj_down_mn)
#print(obj_up_sd)
#print(obj_down_sd)


# In two separate plots, Google and use "plt.errorbar()" to display mean and standard deviation for each of the two conditions
# Condition 1 - face up (left) and face down (right)
plt.figure()

# Label the axes

# Title the graph
plt.title('Face')
plt.xlim([0,3])
plt.show()

# Condition 2 - object up (left) and object down (right)
plt.figure()

# Label the axes

# Title the graph
plt.title('Object')
plt.xlim([0,3])
plt.show()

# To obtain full credits for this exercise, you need to enter the following on to the form http://goo.gl/forms/xF2HwHL2K1
# Standard deviation for face upward condition
# Standard deviation for face downward condition
# Standard deviation for obj updward condition
# Standard deviation for obj downward condition
# Report your conclusions in 1-2 sentences max.
# Copy and paste the Python function you wrote for computing standard deviation
#
# Show the three plots to the instructor either before the class ends, or email those to the instructor before midnight

# Bonus point (0.5): Explain in 1-2 sentences why inversion of face led to a larger difference in response time than inversion of object?
